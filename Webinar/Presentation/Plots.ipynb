# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
Symtree = [1.00,1.00,1.00,1.00,1.00,1.00,1.00,1.00,1.00,1.00,1.00,1.00,1.00,1.00,0.62,1.00,1.00,1.00,0.99,0.99]
ITLS    = [0.93,1.00,0.03 ,1.00,0.97 ,0.00,0.50 ,1.00,0.56 ,1.00,0.07 ,0.97 ,1.00,0.89 ,0.19 ,0.13 ,0.00,0.20 ,0.98 ,0.99]
ITES    = [0.95 ,1.00,0.0,0.93 ,1.00,0.00,0.83 ,1.00,0.63 ,1.00,0.23 ,0.77 ,1.00,0.33 ,0.17 ,0.11 ,0.00,0.17 ,0.98 ,0.99]
Eureqa  = [1.00,1.00,1.00,1.00,1.00,1.00,1.00,1.00,1.00,0.90 ,1.00,1.00,1.00,0.75 ,0.35 ,0.81 ,1.00,0.48 ,0.99 ,1.00]

# %%
df = pd.DataFrame({'SymTree':Symtree, 'IT-LS':ITLS, 'IT-ES':ITES,'Eureqa':Eureqa}, index=np.arange(1,21))

# %%
plot = df[:10][['SymTree','Eureqa']].plot.bar(figsize=(14,14), ylim=(0.4, 1.15), fontsize=20)
plot.legend(loc=1, prop={'size': 20})
plot.set_ylabel('Score', fontsize=20)
plt.savefig('figs/results1.png')

# %%
plot = df[10:][['SymTree','Eureqa']].plot.bar(figsize=(14,14), ylim=(0.4, 1.15), fontsize=20)
plot.legend(loc=1, prop={'size': 20})
plot.set_ylabel('Score', fontsize=20)
plt.savefig('figs/results2.png')
